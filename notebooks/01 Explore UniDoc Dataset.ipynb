# %%
from datasets import load_dataset

# Load the dataset from Hugging Face
dataset = load_dataset("Salesforce/UniDoc-Bench",split="test")

# Access the dataset (contains all 1,742 QA pairs)
data = dataset["test"]
# Out:
# Hello World

# %%
import pandas as pd

finance_df = pd.read_parquet("../data/test/finance-00000-of-00001.parquet")
print(finance_df.head(10))
# Out:
#                                             question  \
# 0  What is the variation in revenue growth betwee...
# 1  In the context of WAM Active's financials, how...
# 2  In the World Political Economy blog, which eco...
# 3  In what way did the ratio of the US federal bu...
# 4  What impact do alterations in mating patterns ...
# 5  What was the variation in the net book value f...
# 6  What impact did shifts in the value of energy ...
# 7  How did the preference between Microsoft's sub...
# 8  Was funding allocated for the call center serv...
# 9  In the period from 1991 to 2011, how did the e...
#
#                                               answer  \
# 0  Firms founded by younger owners in the 2013 gr...
# 1  The NTA before tax in June 2021 was 101.84c, c...
# 2  Regulatory Expansion is an economic concern ti...
# 3  The federal budget deficit as a percentage of ...
# 4  In 2005, changing from assortative to random m...
# 5  The net book value for right-of-use assets rep...
# 6  The overall value of energy-related imports dr...
# 7  The trend shows a significant increase in the ...
# 8  Yes. Funding was included in the 2020 Annual O...
# 9  The current account positions for countries li...
#
#                                       gt_image_paths      question_type  \
# 0     [images/finance/3152577/3152577_page_0014.png]         comparison
# 1  [images/finance/6002966/6002966_page_0009.png,...         comparison
# 2     [images/finance/5510314/5510314_page_0015.png]  factual_retrieval
# 3  [images/finance/4119285/4119285_page_0006.png,...         comparison
# 4  [images/finance/6077605/6077605_page_0004.png,...   causal_reasoning
# 5  [images/finance/5910185/5910185_page_0008.png,...         comparison
# 6  [images/finance/1968605/1968605_page_0007.png,...   causal_reasoning
# 7     [images/finance/1295982/1295982_page_0003.png]         comparison
# 8  [images/finance/6838482/6838482_page_0007.png,...  factual_retrieval
# 9  [images/finance/7689976/7689976_page_0013.png,...      summarization
#
#                  answer_type   domain  \
# 0                  text_only  finance
# 1             table_required  finance
# 2                 image_only  finance
# 3  image_plus_text_as_answer  finance
# 4             table_required  finance
# 5             table_required  finance
# 6  image_plus_text_as_answer  finance
# 7  image_plus_text_as_answer  finance
# 8             table_required  finance
# 9  image_plus_text_as_answer  finance
#
#                                  longdoc_image_paths
# 0  [images/finance/3152577/3152577_page_0001.png,...
# 1  [images/finance/6002966/6002966_page_0001.png,...
# 2  [images/finance/5510314/5510314_page_0001.png,...
# 3  [images/finance/4119285/4119285_page_0001.png,...
# 4  [images/finance/6077605/6077605_page_0001.png,...
# 5  [images/finance/5910185/5910185_page_0001.png,...
# 6  [images/finance/1968605/1968605_page_0001.png,...
# 7  [images/finance/1295982/1295982_page_0001.png,...
# 8  [images/finance/6838482/6838482_page_0001.png,...
# 9  [images/finance/7689976/7689976_page_0001.png,...

# %%
1+1
# Out:
# 2
