# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.query_rewriter import rewrite_query

# %%
query = "I'm trying to figure out if the company's debt situation is getting worse for Apple, considering their Q4 2024, as well as which president Nvidia as now in 2026?"
rewritten_query = rewrite_query(query)
rewritten_query
# Out:
# '{"queries": ["Apple debt Q4 2024", "Nvidia president 2026"]}'
