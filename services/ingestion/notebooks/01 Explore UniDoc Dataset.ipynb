# %% [raw]
# from datasets import load_dataset
#
# # Load the dataset from Hugging Face
# dataset = load_dataset("Salesforce/UniDoc-Bench",split="test")
#
# # Access the dataset (contains all 1,742 QA pairs)
# data = dataset["test"]

# %%
import pandas as pd

finance_df = pd.read_parquet("../data/test/finance-00000-of-00001.parquet")
display(finance_df.head(1))
# Out:
#                                             question  \
# 0  What is the variation in revenue growth betwee...
#
#                                               answer  \
# 0  Firms founded by younger owners in the 2013 gr...
#
#                                    gt_image_paths question_type answer_type  \
# 0  [images/finance/3152577/3152577_page_0014.png]    comparison   text_only
#
#     domain                                longdoc_image_paths
# 0  finance  [images/finance/3152577/3152577_page_0001.png,...

# %%
1+1
# Out:
# 2
